# %% [markdown]
# 1. 다음 리스트에서 400, 500을 삭제하는 code를 입력하세요

# %%
nums = [100, 200, 300, 400, 500]
del nums[3:]
print(nums)
# Out:
# [100, 200, 300]

# %% [markdown]
# 2. pass부분에 리스트 내장함수를 insert를 이용하여 코드를 입력하고 다음과 같이 출력되게 하세요

# %%
I = [200, 100, 300]
I.insert(2, 10000)
print(I)
# Out:
# [200, 100, 10000, 300]

# %% [markdown]
# 3. 다음 출력 값으로 올바른 것은?
# I = [100, 200, 300]
# print(type(I))
# --> 3) class 'list'

# %% [markdown]
# 4. 다음 변수 a를 print(type(a))로 넣었을 때 출력될 값과의 연결이 알맞지 않은 것은?
# --> 3) 입력 : a = 'p', 출력 : class 'char'

# %% [markdown]
# 5. 다음 코드의 출력 값으로 알맞은 것은?
# a = 10
# b = 2
# for i in range(1, 5, 2):
#     a += i
#
# print(a+b)
#
# --> 16
# 1부터 4까지에서 2씩 늘려 i에 대입
# 그러면 i에는 1,3이 대입된다.
# 10+1+3이 되므로 print(14+2) 답은 16

# %% [markdown]
# 6. True를 찾아라
# --> 2) 1
# 이진법에 의해 파이썬에서 0은 False, 1은 True의 의미로 사용된다.

# %% [markdown]
# 7. 다음 중 변수명으로 사용할 수 없는 것 2개를 고르시오.
# --> 3) as
# 5) 1age
# 변수명은 숫자를 사용할 수 있지만 숫자부터 시작하면 안된다.

# %% [markdown]
# 8. 딕셔너리를 다음과 같이 만들었다.
# 출력값을 입력하시오. (출력값은 공백을 넣지 않습니다. )
# d = {'height' : 180, 'weight' : 78, 'weight' : 84, 'temparture' : 36, 'eyesight' : 1}
# print(d['weight'])
#
# --> 84
# 딕셔너리 키 이름이 중복될 때는 가장 뒤에 있는 값만 사용한다.

# %% [markdown]
# 9. 다음 소스 코드를 완성하여 날짜와 시간을 출력하시오.
# year = '2019'
# month = '04'
# day = '26'
# hour = '11'
# minute = '34'
# second = '27'
#
# print(year, month, day, sep='/', end=' ')
# print(hour, minute, second, sep=':')
#
# 출력
# 2019/04/26 11:34:27

# %% [markdown]
# 10. 크리스마스 날, 은비는 친구들과 함께 파티를 하기로 했습니다. 그런데, 크리스마스 트리를 사는 것을 깜빡하고 말았습니다. 온 가게를 돌아다녀 봤지만 크리스마스 트리는 모두 품절이었습니다.
# 하는 수 없이 은비는 프로그래밍으로 트리를 만들기로 합니다.
#
# 은비를 위해 프로그램을 작성해 주세요.

# %%
n = int(input())
for i in range(1, n+1):
    print("  "*(n-i)+("*"*(2*i-1)))
# Out:
# 4
#       *
#     ***
#   *****
# *******
